# %% [markdown]
# # Testing
# ### Bevölkerung nach Herkunft und Geschlecht, seit 1901
# Beschreibung
# Wirtschaftliche Wohnbevölkerung der Stadt Zürich nach Herkunft, Geschlecht und Jahr, seit 1901.
#
# Datum: 14.03.2023

# %% [markdown]
# ### Importiere die notwendigen Packages

# %%
#%pip install geopandas altair fiona requests folium mplleaflet contextily seaborn datetime plotly leafmap

# %%
import altair as alt
import datetime
import folium 
import geopandas as gpd
import io
from IPython.display import Markdown as md
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#import pivottablejs
#from pivottablejs import pivot_ui
import plotly.express as px
import requests
import seaborn as sns

# %% [markdown]
# Importiere die eigenen Funktionen, die unter ../0_scripts abegelegt sind:

# %%
import sys
sys.path.append('../0_scripts')

import my_py_dataviz_functions as mypy_dv
import my_py_dataloading_functions as mypy_dl

# %%
SSL_VERIFY = False
# evtl. SSL_VERIFY auf False setzen wenn die Verbindung zu https://www.gemeinderat-zuerich.ch nicht klappt (z.B. wegen Proxy)
# Um die SSL Verifikation auszustellen, bitte die nächste Zeile einkommentieren ("#" entfernen)
# SSL_VERIFY = False

# %%
if not SSL_VERIFY:
    import urllib3
    urllib3.disable_warnings()

# %% [markdown]
# Definiere Settings. Hier das Zahlenformat von Float-Werten (z.B. *'{:,.2f}'.format* mit Komma als Tausenderzeichen),

# %%
#pd.options.display.float_format = lambda x : '{:,.1f}'.format(x) if (np.isnan(x) | np.isinf(x)) else '{:,.0f}'.format(x) if int(x) == x else '{:,.1f}'.format(x)
pd.options.display.float_format = '{:.0f}'.format
pd.set_option('display.width', 100)
pd.set_option('display.max_columns', 15)

# %% [markdown]
# ### Settings
# Definiere Settings.
# Hier das Zahlenformat von Float-Werten (z.B. *'{:,.2f}'.format* mit Komma als Tausenderzeichen)

# %%
#pd.options.display.float_format = lambda x : '{:,.1f}'.format(x) if (np.isnan(x) | np.isinf(x)) else '{:,.0f}'.format(x) if int(x) == x else '{:,.1f}'.format(x)
pd.options.display.float_format = '{:.0f}'.format
pd.set_option('display.width', 100)
pd.set_option('display.max_columns', 15)

# %% [markdown]
# #### Zeitvariabeln

# %%
#Zeitvariabeln als Strings:
now = datetime.date.today()
year_today = now.strftime("%Y")
date_today = "_"+now.strftime("%Y-%m-%d")

#Zeitvariabeln als Integers:
int_times = now.timetuple()
aktuellesJahr = int_times[0]
aktuellerMonat = int_times[1]
selectedMonat = int_times[1]-2
#print(aktuellesJahr, aktuellerMonat,'datenstand: ', selectedMonat, int_times)

# %% [markdown]
# ### Daten importieren und Metadaten checken
#
# - status: int / prod
# - data_source: web / ld / dropzone
# - datums_attr: beschreibt das oder die Datumsfelder, die als Datum geparsed werden sollen. Falls es keines gibt: None

# %%
#speichere die variable global, damit ich sie später verwenden kann, wenn ich grafiken mit diesem namen speichere.
package_name = "BEV322OD3222"

# %%
data2betested = mypy_dl.load_data(
    status = 'int'
    , data_source = 'web'
    , package_name = "bev_bestand_jahr_herkunft_geschlecht_od3222"
    , dataset_name = "BEV322OD3222"    
    , datums_attr = ['StichtagDatJahr']
    )
# Out:
# fp lautet:https://data.integ.stadt-zuerich.ch/dataset/int_dwh_bev_bestand_jahr_herkunft_geschlecht_od3222/download/BEV322OD3222.csv
#  **Überprüfe die Metadaten:**
#  **Dataset auf INTEG-Datakatalog:** Link https://data.integ.stadt-zuerich.ch/dataset/int_dwh_bev_bestand_jahr_herkunft_geschlecht_od3222
#  **Dataset auf PROD-Datakatalog:** Link https://data.stadt-zuerich.ch/dataset/bev_bestand_jahr_herkunft_geschlecht_od3222
# data_source: web

# %%
data2betested.head(2)
# Out:
#   StichtagDatJahr DatenstandCd  HerkunftCd  HerkunftLang  SexCd    SexLang  AnzBestWir
# 0      1901-01-01            D           1  Schweizer*in    252  unbekannt      108291
# 1      1901-01-01            D           2  Ausländer*in    252  unbekannt       42010

# %% [markdown]
# Berechne weitere Attribute falls notwendig

# %%
data2betested = (
    data2betested
    .copy()
    .assign(
        #Aktualisierungs_Datum_str= lambda x: x.Aktualisierungs_Datum.astype(str),
        Jahr = lambda x: x.StichtagDatJahr,
        Jahr_str = lambda x: x.Jahr.astype(str),
        Jahr_nbr = lambda x: x.Jahr.dt.year,
    )
    .sort_values('Jahr', ascending=False)
    )
data2betested.dtypes
# Out:
# StichtagDatJahr    datetime64[ns]
# DatenstandCd               object
# HerkunftCd                  int64
# HerkunftLang               object
# SexCd                       int64
# SexLang                    object
# AnzBestWir                  int64
# Jahr               datetime64[ns]
# Jahr_str                   object
# Jahr_nbr                    int32
# dtype: object

# %% [markdown]
# Minimales und maximales Jahr im Datensatz

# %%
data_max_date = str(max(data2betested.Jahr).year)
data_min_date = str(min(data2betested.Jahr).year)

print(f"Die Daten haben ein Minimumjahr von {data_min_date} und ein Maximumjahr von {data_max_date}")
# Out:
# Die Daten haben ein Minimumjahr von 1901 und ein Maximumjahr von 2024

# %% [markdown]
# ### Einfache Datentests

# %%
data2betested.head(2).T
# Out:
#                                  429                  428
# StichtagDatJahr  2024-01-01 00:00:00  2024-01-01 00:00:00
# DatenstandCd                       D                    D
# HerkunftCd                         2                    2
# HerkunftLang            Ausländer*in         Ausländer*in
# SexCd                              2                    1
# SexLang                     weiblich             männlich
# AnzBestWir                     70418                80978
# Jahr             2024-01-01 00:00:00  2024-01-01 00:00:00
# Jahr_str                  2024-01-01           2024-01-01
# Jahr_nbr                        2024                 2024

# %%
data2betested.shape
# Out:
# (430, 10)

# %% [markdown]
# Beschreibe einzelne Attribute

# %%
data2betested.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 430 entries, 429 to 0
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   StichtagDatJahr  430 non-null    datetime64[ns]
#  1   DatenstandCd     430 non-null    object
#  2   HerkunftCd       430 non-null    int64
#  3   HerkunftLang     430 non-null    object
#  4   SexCd            430 non-null    int64
#  5   SexLang          430 non-null    object
#  6   AnzBestWir       430 non-null    int64
#  7   Jahr             430 non-null    datetime64[ns]
#  8   Jahr_str         430 non-null    object
#  9   Jahr_nbr         430 non-null    int32
# dtypes: datetime64[ns](2), int32(1), int64(3), object(4)
# memory usage: 144.7 KB

# %%
print(f'The dataset has {data2betested.shape[0]:,.0f} rows (observations) and {data2betested.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {data2betested.duplicated().sum()} exact duplicates in the data.')
# Out:
# The dataset has 430 rows (observations) and 10 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %% [markdown]
# Welches sind die Quartiere ohne Werte bei AnzBestWir?

# %%
data2betested[np.isnan(data2betested.AnzBestWir)].head()
# Out:
# Empty DataFrame
# Columns: [StichtagDatJahr, DatenstandCd, HerkunftCd, HerkunftLang, SexCd, SexLang, AnzBestWir, Jahr, Jahr_str, Jahr_nbr]
# Index: []

# %% [markdown]
# ### Verwende das Datum als Index
#
# While we did already parse the `datetime` column into the respective datetime type, it currently is just a regular column.
# **To enable quick and convenient queries and aggregations, we need to turn it into the index of the DataFrame**

# %%
data2betested = data2betested.set_index("Jahr")
data2betested = data2betested.sort_index()

# %%
#data2betested.info()
data2betested.index.year.unique()
# Out:
# Index([1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910,
#        ...
#        2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024],
#       dtype='int32', name='Jahr', length=124)

# %% [markdown]
# ### Beschreibe einzelne Attribute

# %% [markdown]
# Beschreibe nicht numerische Attribute

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(data2betested.describe(exclude='number',datetime_is_numeric=True))
except:
    print("No categorical data in dataset.")
# Out:
# No categorical data in dataset.

# %% [markdown]
# Beschreibe numerische Attribute

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.0f}'.format):
        display(data2betested.describe(include='number'))
except:
    print("No numercial data in dataset.")
# Out:
#        HerkunftCd  SexCd  AnzBestWir  Jahr_nbr
# count         430    430         430       430
# mean            2     40      97,308     1,969
# std             1     90      61,356        33
# min             1      1       9,980     1,901
# 25%             1      1      37,735     1,944
# 50%             2      2      94,634     1,971
# 75%             2      2     150,749     1,998
# max             2    252     230,254     2,024

# %%
plt.style.use('ggplot')
params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }
plt.rcParams.update(params)

try:
    data2betested.hist(bins=25, rwidth=0.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %% [markdown]
# ### Gibt es Duplikate?

# %%
# find duplicate rows
duplicate_rows = data2betested[data2betested.duplicated()]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [StichtagDatJahr, DatenstandCd, HerkunftCd, HerkunftLang, SexCd, SexLang, AnzBestWir, Jahr_str, Jahr_nbr]
# Index: []

# %% [markdown]
# ### Nullwerte und Missings?

# %%
data2betested.isnull().sum()
# Out:
# StichtagDatJahr    0
# DatenstandCd       0
# HerkunftCd         0
# HerkunftLang       0
# SexCd              0
# SexLang            0
# AnzBestWir         0
# Jahr_str           0
# Jahr_nbr           0
# dtype: int64

# %% [markdown]
# ### Gruppierungen

# %%
agg_jahr = data2betested.loc[data_min_date:data_max_date]\
    .groupby(['Jahr']) \
    .agg(sum_AnzBestWir=('AnzBestWir', 'sum')) \
    .sort_values('Jahr', ascending=False) 
agg_jahr.reset_index().head(3)
# Out:
#         Jahr  sum_AnzBestWir
# 0 2024-01-01          448664
# 1 2023-01-01          447082
# 2 2022-01-01          443037

# %%
data2betested.columns
# Out:
# Index(['StichtagDatJahr', 'DatenstandCd', 'HerkunftCd', 'HerkunftLang', 'SexCd', 'SexLang',
#        'AnzBestWir', 'Jahr_str', 'Jahr_nbr'],
#       dtype='object')

# %%
agg_Herk = data2betested.loc[data_min_date:data_max_date]\
    .groupby(['HerkunftCd', 'HerkunftLang',]) \
    .agg(sum_AnzBestWir=('AnzBestWir', 'sum')) \
    .sort_values('HerkunftCd', ascending=False) 
agg_Herk.reset_index().head(50)
# Out:
#    HerkunftCd  HerkunftLang  sum_AnzBestWir
# 0           2  Ausländer*in         8664359
# 1           1  Schweizer*in        33178276

# %% [markdown]
# ### Zeitpunkte und Zeiträume abfragen
#
# A particular powerful feature of the Pandas DataFrame is its indexing capability that also works using time-based entities, such as dates and times. We have already created the index above, so let's put it to use.

# %%
data2betested.loc[data_max_date].head(2)
#data2betested.loc["2021-10-31":"2021-11-30"].head(2)
# Out:
#            StichtagDatJahr DatenstandCd  HerkunftCd  HerkunftLang  SexCd   SexLang  AnzBestWir  \
# Jahr
# 2024-01-01      2024-01-01            D           1  Schweizer*in      1  männlich      144674
# 2024-01-01      2024-01-01            D           1  Schweizer*in      2  weiblich      152594
#
#               Jahr_str  Jahr_nbr
# Jahr
# 2024-01-01  2024-01-01      2024
# 2024-01-01  2024-01-01      2024

# %% [markdown]
# ### Visualisierungen nach Zeitausschnitten

# %% [markdown]
# #### Entwicklung Bildungsstand

# %%
data2betested.columns
# Out:
# Index(['StichtagDatJahr', 'DatenstandCd', 'HerkunftCd', 'HerkunftLang', 'SexCd', 'SexLang',
#        'AnzBestWir', 'Jahr_str', 'Jahr_nbr'],
#       dtype='object')

# %%
#myAgg = data2betested.loc["2008-11-30":"2021-10-31"]
myAgg1 = data2betested.loc[data_min_date:data_max_date]\
    .groupby(['Jahr', 'Jahr_nbr', 'HerkunftCd', 'HerkunftLang',]) \
    .agg(sum_AnzBestWir=('AnzBestWir', 'sum')) \
    .sort_values('Jahr', ascending=True) 

myAgg1.reset_index().head(3)
# Out:
#         Jahr  Jahr_nbr  HerkunftCd  HerkunftLang  sum_AnzBestWir
# 0 1901-01-01      1901           1  Schweizer*in          108291
# 1 1901-01-01      1901           2  Ausländer*in           42010
# 2 1902-01-01      1902           1  Schweizer*in          110707

# %%
myAgg1.reset_index().to_excel('//szh.loc/ssz/data/GIS/Sandbox/2024/nzz/test.xlsx', index=False)

# %%
grafik1 = mypy_dv.plot_altair_multiline_highlight(
    data = myAgg1.reset_index()
    , x = 'Jahr:T'
    , y = 'sum_AnzBestWir:Q'
    , myTitle = "Entwicklung der Wohnbevölkerung nach Herkunft, seit "+str(data2betested.index.year.min())
    , x_beschriftung = 'Jahr'
    , y_beschriftung = 'Anz. Personen'
    , warning_status  = "ignore"
    , category='HerkunftLang:N'
    , category_beschriftung='Herkunft:'
)

# %%
grafik1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# #### Barcharts mit Seaborn

# %%
#help(sns.catplot)

# %%
#Stile for the following sns graphs
sns.set_theme(style="whitegrid")

# %%
data2betested.columns
# Out:
# Index(['StichtagDatJahr', 'DatenstandCd', 'HerkunftCd', 'HerkunftLang', 'SexCd', 'SexLang',
#        'AnzBestWir', 'Jahr_str', 'Jahr_nbr'],
#       dtype='object')

# %%
faced_grid1 = mypy_dv.plot_sns_facetgrid(
    data = data2betested.reset_index()
    , col = "HerkunftLang"
    , hue = "SexLang"
    , col_wrap = 2
    , height = 3
    , grafiktyp = sns.lineplot
    , x = "Jahr"
    , y = "AnzBestWir"
    , ylabel= "Anzahl Persone"
    )

# %% [markdown]
# ## ---------------------- hier Plausi beendet
#
# **Sharepoint als gecheckt markieren!**

# %% [markdown]
# Record auf Sharepoint: **[Link](https://kollaboration.intranet.stzh.ch/orga/ssz-produkte/Lists/SASA_Outputs/DispForm.aspx?ID=41&ContentTypeId=0x0100988EAF029F1EFE4CA675F53C32A5D53D01006DBC563E6FBE9E4EB6FDC780799752E1)**
#
# ---------------------------------------------------------------------------
